# %%
from IPython import get_ipython
get_ipython().run_line_magic('reset -sf')

# CHANGE THE FILE PATHS BELOW FOR YOUR COMPUTER
fp_folder = '/Users/yasminebassil/Desktop/YA_Data/' # filepath to data
fp_code = '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/data_analysis/' # filepath to codes

# %store fp_folder
get_ipython().run_line_magic('run', fp_code + '1_calculate_outcomes.ipynb')
get_ipython().run_line_magic('run', fp_code + '2_merge_data.ipynb')
#make sure to change save location at the end of script
get_ipython().run_line_magic('run', fp_code + '3_average_data.ipynb')
#make sure to change save location at the end of script
get_ipython().run_line_magic('run', fp_code + '4_target_data.ipynb')
get_ipython().run_line_magic('run', fp_code + '5_graph_data.ipynb')
print("Complete")
# Out:
# Stored 'fp_folder' (str)
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_32988/2181713863.py:2: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -sf')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_32988/3455941148.py:2
#       1 # Retrieving filepath to all data folders
# ----> 2 get_ipython().run_line_magic('store', '-r fp_folder')
#       4 sub_folders = []
#       5 for i in os.listdir(fp_folder):
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/extensions/storemagic.py:148, in StoreMagics.store(self, parameter_s)
#     146 for arg in args:
#     147     try:
# --> 148         obj = db['autorestore/' + arg]
#     149     except KeyError:
#     150         try:
#
# TypeError: 'PickleShareDB' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6 fp_code = '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/data_analysis/' # filepath to codes
#       8 get_ipython().run_line_magic('store', 'fp_folder')
# ----> 9 get_ipython().run_line_magic('run', fp_code + '1_calculate_outcomes.ipynb')
#      10 get_ipython().run_line_magic('run', fp_code + '2_merge_data.ipynb')
#      11 #make sure to change save location at the end of script
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2981, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2979 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2980 if raise_exceptions:
# -> 2981     result.raise_error()
#    2982 elif not result.success:
#    2983     break
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:294, in ExecutionResult.raise_error(self)
#     292     raise self.error_before_exec
#     293 if self.error_in_exec is not None:
# --> 294     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_32988/3455941148.py:2
#       1 # Retrieving filepath to all data folders
# ----> 2 get_ipython().run_line_magic('store', '-r fp_folder')
#       4 sub_folders = []
#       5 for i in os.listdir(fp_folder):
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/Emory/3_Research/Projects/CogMap_Paper/.venv/lib/python3.11/site-packages/IPython/extensions/storemagic.py:148, in StoreMagics.store(self, parameter_s)
#     146 for arg in args:
#     147     try:
# --> 148         obj = db['autorestore/' + arg]
#     149     except KeyError:
#     150         try:
#
# TypeError: 'PickleShareDB' object is not subscriptable
