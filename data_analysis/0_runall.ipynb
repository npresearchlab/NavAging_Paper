# %%
from IPython import get_ipython
get_ipython().magic('reset -sf')


# CHANGE THE FILE PATHS BELOW FOR YOUR COMPUTER

#YB File Paths
fp_folder = '/Volumes/YB_Drive/NavAging_Paper/data/OA_Data/' # filepath to data
fp_code = '/Volumes/YB_Drive/NavAging_Paper/data_analysis/' # filepath to codes

#AK File Paths

# %store fp_folder
get_ipython().run_line_magic('run', fp_code + '1_calculate_outcomes.ipynb')
get_ipython().run_line_magic('run', fp_code + '2_merge_data.ipynb')
#make sure to change save location at the end of script
get_ipython().run_line_magic('run', fp_code + '3_average_data.ipynb')
#make sure to change save location at the end of script
get_ipython().run_line_magic('run', fp_code + '4_target_data.ipynb')
get_ipython().run_line_magic('run', fp_code + '5_graph_data.ipynb')
print("Complete")
# Out:
# Stored 'fp_folder' (str)
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_38139/3082725449.py:2: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -sf')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/IPython/core/magics/execution.py:701, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     700     fpath = arg_lst[0]
# --> 701     filename = file_finder(fpath)
#     702 except IndexError as e:
#
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'/Volumes/YB_Drive/NavAging_Paper/data_analysis1_calculate_outcomes.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 #AK File Paths
#      13 get_ipython().run_line_magic('store', 'fp_folder')
# ---> 14 get_ipython().run_line_magic('run', fp_code + '1_calculate_outcomes.ipynb')
#      15 get_ipython().run_line_magic('run', fp_code + '2_merge_data.ipynb')
#      16 #make sure to change save location at the end of script
#
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2414, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2412     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2413 with self.builtin_trap:
# -> 2414     result = fn(*args, **kwargs)
#    2416 # The code below prevents the output from being displayed
#    2417 # when using magics with decodator @output_can_be_silenced
#    2418 # when the last Python token in the expression is a ';'.
#    2419 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/IPython/core/magics/execution.py:712, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     710     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     711         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 712     raise Exception(msg) from e
#     713 except TypeError:
#     714     if fpath in sys.meta_path:
#
# Exception: File `'/Volumes/YB_Drive/NavAging_Paper/data_analysis1_calculate_outcomes.ipynb'` not found.
