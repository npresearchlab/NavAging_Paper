# %%
from IPython import get_ipython
get_ipython().magic('reset -sf')

# Define the list of folder paths to process
fp_folders = [
    '/Volumes/YB_Drive/NavAging_Paper/data/YA_Data/', #change this based on where data is stored
    '/Volumes/YB_Drive/NavAging_Paper/data/OA_Data/' #change this based on where data is stored
]

fp_code = '/Volumes/YB_Drive/NavAging_Paper/data_analysis/' # filepath to codes

# Loop through each folder path
for i, fp_folder in enumerate(fp_folders):
    print(f"Processing folder {i+1}/{len(fp_folders)}: {fp_folder}")
    
    # Store the current folder path
    # %store fp_folder
    
    # Run the analysis scripts
    get_ipython().run_line_magic('run', fp_code + '1_calculate_outcomes.ipynb')
    get_ipython().run_line_magic('run', fp_code + '2_merge_data.ipynb')
    #make sure to change save location at the end of script
    get_ipython().run_line_magic('run', fp_code + '3_average_data.ipynb')
    #make sure to change save location at the end of script
    get_ipython().run_line_magic('run', fp_code + '4_target_data.ipynb')
    get_ipython().run_line_magic('run', fp_code + '5_graph_data.ipynb')
    
    print(f"Completed processing for: {fp_folder}")
    print("-" * 50)

print("All processing complete!")
# Out:
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_63122/3017260140.py:2: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -sf')
# Stored 'fp_folder' (str)
# ['BNC01', 'BNC02', 'BNC03', 'BNC04', 'BNC05', 'BNC07', 'BNC08', 'BNC09', 'BNC11', 'BNC12', 'BNC23', 'BNC26', 'BNC27', 'BNC28', 'BNC29', 'BNC30', 'BNC31', 'BNC32', 'BNC33', 'BNC34', 'BNC35', 'BNC36', 'BNC37', 'BNC50', 'BNC51', 'BNC52', 'NAV054', 'NAV055', 'NAV056', 'NAV061']
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_63122/4279315902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_Diff'] = df['X'].diff()
# ...
